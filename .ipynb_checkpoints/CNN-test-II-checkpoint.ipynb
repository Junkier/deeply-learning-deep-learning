# %%
import os , pickle
from os.path import isfile , join

def unpickle(file):
    fo = open(file,"rb")
    dict_qq = pickle.load(fo , encoding="latin1")
    fo.close()
    return dict_qq



classes = 10

dataset_path = "./cifar_10/"

trains_fn = [fn for fn in os.listdir(dataset_path) if isfile(join(dataset_path , fn )) and fn.startswith("data_batch")]

trains_fn.sort()

fn = trains_fn[0]

raw_data = unpickle(dataset_path  + fn)

# Show images
testQQ  = raw_data["data"][1].reshape(3,32,32).transpose([1,2,0])
plt.imshow(testQQ)

# %%
testQQ  = raw_data["data"][1].reshape(3,32,32).transpose([1,2,0])
plt.imshow(testQQ)

# %%
# Show total images
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
from six.moves import cPickle 

num = 10
X = raw_data["data"] 
Y = raw_data['labels']
X = X.reshape(10000, 3, 32, 32).transpose(0,2,3,1).astype("uint8")
Y = np.array(Y)

# Visualizing CIFAR 10
fig, axes1 = plt.subplots(num,num,figsize=(3,3))
for j in range(num):
    for k in range(num):
        i = np.random.choice(range(len(X)))
        axes1[j][k].set_axis_off()
        axes1[j][k].imshow(X[i:i+1][0])

# %%
names[180]
# Out:
# 'fallow_deer_s_001164.png'
